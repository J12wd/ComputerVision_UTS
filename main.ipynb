# %%
# !pip3 install numpy matplotlib seaborn scikit-image scikit-learn mlxtend
# Out:
# Requirement already satisfied: numpy in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.2)
# Requirement already satisfied: matplotlib in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-image in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.26.0)
# Requirement already satisfied: scikit-learn in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.8.0)
# Requirement already satisfied: mlxtend in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.24.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (2026.5.15)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-image) (0.5)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tzdata in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\USER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # **1. Dataset Preparation**

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

from skimage.feature import hog
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from mlxtend.data import loadlocal_mnist

# %%
import os

folder_path = r"C:\Users\USER\OneDrive\Dokumen\Computer Vision\dataset"

print(os.path.exists(folder_path))
# Out:
# True

# %%
import os

os.chdir(r"C:\Users\USER\OneDrive\Dokumen\Computer Vision\dataset")

print("Current Directory:")
print(os.getcwd())

print("\nIsi Folder:")
print(os.listdir())
# Out:
# Current Directory:
# C:\Users\USER\OneDrive\Dokumen\Computer Vision\dataset
#
# Isi Folder:
# ['emnist-letters-train-images-idx3-ubyte', 'emnist-letters-train-labels-idx1-ubyte', 'main.ipynb']

# %%
from mlxtend.data import loadlocal_mnist

data_images, data_labels = loadlocal_mnist(
    images_path="emnist-letters-train-images-idx3-ubyte",
    labels_path="emnist-letters-train-labels-idx1-ubyte"
)

# %%
plt.imshow(data_images[0].reshape(28,28).T, cmap='gray')
plt.title(f"Label: {data_labels[0]}")
plt.show()

# %%
print("Jumlah gambar:", len(data_images))
print("Jumlah label :", len(data_labels))
# Out:
# Jumlah gambar: 124800
# Jumlah label : 124800

# %%
data_labels = data_labels - 1

# %%
data_images = np.array(data_images)
data_labels = np.array(data_labels)

selected_images = []
selected_labels = []

for class_idx in range(26):
    idx = np.where(data_labels == class_idx)[0]
    if len(idx) >= 100:
        selected_idx = np.random.choice(idx, 100, replace=False)
        selected_images.append(data_images[selected_idx])
        selected_labels.append(data_labels[selected_idx])
    else:
        print(f"Kelas {class_idx} kosong, hanya ada {len(idx)} gambar.")

X_subset = np.vstack(selected_images)
y_subset = np.hstack(selected_labels)

print("Jumlah x_subset:", len(X_subset))
print("Jumlah y_subset :", len(y_subset))
# Out:
# Jumlah x_subset: 2600
# Jumlah y_subset : 2600

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_subset, y_subset, test_size=0.2, random_state=42, stratify=y_subset
)

print("Jumlah x_train:", len(X_train))
print("Jumlah y_train :", len(y_train))
print("Jumlah x_test :", len(X_test))
print("Jumlah y_test :", len(y_test))
# Out:
# Jumlah x_train: 2080
# Jumlah y_train : 2080
# Jumlah x_test : 520
# Jumlah y_test : 520

# %% [markdown]
# # **2. Feature Extraction**

# %%
feature, hog_img = hog(X_train[0].reshape(28,28), orientations=8, pixels_per_cell=(4, 4), cells_per_block=(2,2), visualize=True, block_norm='L2')

feature.shape
# Out:
# (1152,)

# %%
plt.bar(list(range(feature.shape[0])), feature)
# Out:
# <BarContainer object of 1152 artists>

# %%
def hog_features(images, orientations=8, pixels_per_cell=(8, 8), cells_per_block=(2, 2)):
    features = []
    for image in images:
        feature = hog(image.reshape(28, 28), orientations=orientations,
                      pixels_per_cell=pixels_per_cell,
                      cells_per_block=cells_per_block,
                      block_norm='L2')
        features.append(feature)
    return np.array(features)

# %%
orientations = 8
pixels_per_cell = (4, 4)
cells_per_block = (2, 2)

# %%
X_train_hog = hog_features(X_train, orientations, pixels_per_cell, cells_per_block)
X_test_hog = hog_features(X_test, orientations, pixels_per_cell, cells_per_block)

# %%
print("X_train_hog shape:", X_train_hog.shape)
print("X_test_hog shape :", X_test_hog.shape)
# Out:
# X_train_hog shape: (2080, 1152)
# X_test_hog shape : (520, 1152)

# %% [markdown]
# # **3. Classification**

# %%
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

# %%
svm = SVC()
grid_search = GridSearchCV(svm, param_grid, cv=2, n_jobs=-1, verbose=2)

# %%
grid_search.fit(X_train_hog, y_train)
# Out:
# Fitting 2 folds for each of 30 candidates, totalling 60 fits
# GridSearchCV(cv=2, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Performance:", grid_search.best_estimator_.score(X_test_hog, y_test))
# Out:
# Best Parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Performance: 0.8115384615384615

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# # **4. Evaluation**

# %%
y_test_pred = best_model.predict(X_test_hog)

print("=== Test Set Evaluation ===")
print("Accuracy :", accuracy_score(y_test, y_test_pred))
print("\nClassification Report:\n", classification_report(y_test, y_test_pred))
# Out:
# === Test Set Evaluation ===
# Accuracy : 0.8115384615384615
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        20
#            1       0.90      0.90      0.90        20
#            2       0.86      0.95      0.90        20
#            3       0.71      0.85      0.77        20
#            4       0.95      0.90      0.92        20
#            5       0.83      0.75      0.79        20
#            6       0.63      0.60      0.62        20
#            7       0.79      0.95      0.86        20
#            8       0.55      0.55      0.55        20
#            9       0.90      0.90      0.90        20
#           10       1.00      0.75      0.86        20
#           11       0.50      0.60      0.55        20
#           12       0.95      0.90      0.92        20
#           13       0.89      0.85      0.87        20
#           14       0.89      0.85      0.87        20
#           15       0.78      0.70      0.74        20
#           16       0.62      0.50      0.56        20
#           17       0.80      0.80      0.80        20
#           18       0.90      0.90      0.90        20
#           19       0.89      0.85      0.87        20
#           20       0.82      0.70      0.76        20
#           21       0.78      0.90      0.84        20
#           22       0.90      0.90      0.90        20
#           23       0.90      0.95      0.93        20
#           24       0.85      0.85      0.85        20
#           25       0.86      0.95      0.90        20
#
#     accuracy                           0.81       520
#    macro avg       0.82      0.81      0.81       520
# weighted avg       0.82      0.81      0.81       520

# %%
cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[chr(i + 97) for i in range(26)], yticklabels=[chr(i + 97) for i in range(26)])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
indices = random.sample(range(len(X_test)), 10)

for i, idx in enumerate(indices):
    img = X_test[idx].reshape(28, 28).T 
    true_label = y_test[idx] 
    pred_label = y_test_pred[idx] 

    plt.subplot(2, 5, i + 1)
    plt.imshow(img, cmap='gray')
    plt.title(f"T:{chr(true_label + 97)} | P:{chr(pred_label + 97)}") 
    plt.axis('off')

plt.suptitle("T: True, P: Predicted (huruf a-z)")
plt.tight_layout()
plt.show()
